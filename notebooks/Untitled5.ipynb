# %%
import pandas as pd
df = pd.read_csv('students_performance_data.csv')

# %%
df.describe()
# Out:
#                 Age      Semester  Attendance (%)  Midterm_Score  \
# count  10000.000000  10000.000000     9397.000000   10000.000000
# mean      21.283700      4.155200       65.323773      50.999104
# std        2.478191      2.226254       11.410746      16.366411
# min       18.000000      1.000000       23.161495      20.000000
# 25%       19.000000      2.000000       57.753435      38.980000
# 50%       21.000000      4.000000       65.678707      52.135000
# 75%       23.000000      6.000000       73.319787      63.072500
# max       28.000000      8.000000      100.000000     100.000000
#
#        Assignments_Avg   Quizzes_Avg  Participation_Score  Projects_Score  \
# count     10000.000000  10000.000000          9131.000000    10000.000000
# mean          5.247763      4.242203             5.177750        8.757362
# std           1.613186      1.460156             1.896645        2.952481
# min           0.000000      0.000000             1.000000        0.000000
# ...
