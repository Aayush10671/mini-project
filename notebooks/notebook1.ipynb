# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('StudP.csv')

# %%
df
# Out:
#       Gender  Age  Semester Branch Difficulty_Level  Attendance (%)  \
# 0       Male   25         7     ME             Hard       83.119601
# 1     Female   26         8    CSE             Hard       80.146477
# 2     Female   21         4    CSE         Moderate       47.776656
# 3       Male   20         2     ME             Easy       70.245418
# 4       Male   22         5    ECE         Moderate       92.457907
# ...      ...  ...       ...    ...              ...             ...
# 9995  Female   20         2  Civil             Easy       71.866994
# 9996  Female   24         6     ME             Hard       68.498687
# 9997  Female   19         2    CSE             Easy             NaN
# 9998    Male   26         8    ECE             Hard       62.939364
# 9999    Male   25         7    CSE             Hard       68.027305
#
#       Midterm_Score  Assignments_Avg  Quizzes_Avg  Participation_Score  \
# 0         43.602889        57.313551    61.267100             2.189965
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   10000 non-null  object
#  1   Age                      10000 non-null  int64
#  2   Semester                 10000 non-null  int64
#  3   Branch                   10000 non-null  object
#  4   Difficulty_Level         10000 non-null  object
#  5   Attendance (%)           9146 non-null   float64
#  6   Midterm_Score            10000 non-null  float64
#  7   Assignments_Avg          10000 non-null  float64
#  8   Quizzes_Avg              10000 non-null  float64
#  9   Participation_Score      9106 non-null   float64
#  10  Projects_Score           10000 non-null  float64
#  11  Study_Hours_per_Week     8793 non-null   float64
#  12  Internet_Access_at_Home  10000 non-null  object
#  13  Parent_Education_Level   7995 non-null   object
# ...

# %%
df.describe()
# Out:
#                 Age      Semester  Attendance (%)  Midterm_Score  \
# count  10000.000000  10000.000000     9146.000000   10000.000000
# mean      22.042400      4.540900       75.086273      64.889480
# std        2.353074      2.301707       14.135381      14.838878
# min       18.000000      1.000000       23.679306      20.000000
# 25%       20.000000      3.000000       65.327423      54.802866
# 50%       22.000000      5.000000       75.259900      64.896744
# 75%       24.000000      7.000000       85.385109      75.061188
# max       26.000000      8.000000      100.000000     100.000000
#
#        Assignments_Avg   Quizzes_Avg  Participation_Score  Projects_Score  \
# count     10000.000000  10000.000000          9106.000000    10000.000000
# mean         70.021602     68.061132             5.976638       19.972879
# std          11.818102     13.889152             1.940925        4.939312
# min          30.000000     20.000000             1.000000        5.000000
# ...

# %%
# Correct - use & between conditions, and wrap each condition in parentheses
df_filtered = df[(df['Final_Score'] > 70) & (df['Final_Score'] < 80)]

# %%
df["Grade"].value_counts()
# Out:
# Grade
# C    3828
# B    2511
# D    2357
# F     787
# A     436
# E      81
# Name: count, dtype: int64

# %%
if (df['Final_Score'] >= 70).any():
    df.loc[df['Final_Score'] >= 70, 'Final_Score'] = df['Final_Score'] + 11

# %%
def calculate_grade(score):
    if pd.isna(score):
        return 'Unknown'
    if score >= 90:
        return 'O'
    elif score >= 80:
        return 'E'
    elif score >= 70:
        return 'A'
    elif score >= 60:
        return 'B'
    elif score >= 50:
        return 'C'
    elif score >= 40:
        return 'D'
    else:
        return 'F'


df['Grade'] = df['Final_Score'].apply(calculate_grade)

# %%
df["Grade"].value_counts()
# Out:
# Grade
# C    3828
# B    2511
# D    2357
# F     787
# E     432
# O      85
# Name: count, dtype: int64

# %%
df.loc[(df['Final_Score'] >= 58) & (df['Final_Score'] < 91), 'Final_Score'] += 2

# %%
df['Grade'] = df['Final_Score'].apply(calculate_grade)

# %%
df["Grade"].value_counts()
# Out:
# Grade
# C    3073
# B    2956
# D    2357
# F     787
# E     407
# A     310
# O     110
# Name: count, dtype: int64

# %%
df.loc[(df['Final_Score'] >= 58) & (df['Final_Score'] < 91), 'Final_Score'] += 3

# %%
df['Grade'] = df['Final_Score'].apply(calculate_grade)

# %%
df["Grade"].value_counts()
# Out:
# Grade
# C    3073
# D    2357
# B    2317
# A     949
# F     787
# E     319
# O     198
# Name: count, dtype: int64

# %%
df.loc[(df['Final_Score'] >= 58) & (df['Final_Score'] < 91), 'Final_Score'] += 2

# %%
df['Grade'] = df['Final_Score'].apply(calculate_grade)

# %%
df["Grade"].value_counts()
# Out:
# Grade
# C    3073
# D    2357
# B    1755
# A    1511
# F     787
# O     313
# E     204
# Name: count, dtype: int64

# %%
df.loc[(df['Final_Score'] >= 58) & (df['Final_Score'] < 81), 'Final_Score'] += 2

# %%
df['Grade'] = df['Final_Score'].apply(calculate_grade)

# %%
df["Grade"].value_counts()
# Out:
# Grade
# C    3073
# D    2357
# A    2154
# B    1112
# F     787
# O     313
# E     204
# Name: count, dtype: int64

# %%
df.loc[(df['Final_Score'] >= 58) & (df['Final_Score'] < 81), 'Final_Score'] += 2
df['Grade'] = df['Final_Score'].apply(calculate_grade)
df["Grade"].value_counts()
# Out:
# Grade
# C    3073
# A    2755
# D    2357
# F     787
# B     368
# E     347
# O     313
# Name: count, dtype: int64

# %%
df.loc[(df['Final_Score'] >= 58) & (df['Final_Score'] < 81), 'Final_Score'] += 2
df['Grade'] = df['Final_Score'].apply(calculate_grade)
df["Grade"].value_counts()
# Out:
# Grade
# C    3073
# A    2747
# D    2357
# F     787
# E     723
# O     313
# Name: count, dtype: int64

# %%
df[df['Final_Score']>=90]
# Out:
#       Gender  Age  Semester Branch Difficulty_Level  Attendance (%)  \
# 4       Male   22         5    ECE         Moderate       92.457907
# 12    Female   18         1    CSE             Easy       85.273624
# 81      Male   18         1    ECE             Easy       80.708321
# 110     Male   20         2  Civil             Easy       80.227981
# 132     Male   23         6     ME             Hard       62.781625
# ...      ...  ...       ...    ...              ...             ...
# 9860  Female   23         6    CSE             Hard       94.940354
# 9863  Female   19         2    CSE             Easy       77.073368
# 9968  Female   19         1    CSE             Easy       59.679924
# 9984  Female   20         3    CSE         Moderate      100.000000
# 9993  Female   19         2    CSE             Easy       76.035911
#
#       Midterm_Score  Assignments_Avg  Quizzes_Avg  Participation_Score  \
# 4         80.381252       100.000000    65.223913             4.450505
# ...

# %%
df.loc[(df['Final_Score'] >= 58) & (df['Final_Score'] < 95), 'Final_Score'] += 2
df['Grade'] = df['Final_Score'].apply(calculate_grade)
df["Grade"].value_counts()
# Out:
# Grade
# C    3073
# D    2357
# A    2317
# E     949
# F     787
# O     517
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                 Age      Semester  Attendance (%)  Midterm_Score  \
# count  10000.000000  10000.000000     9146.000000   10000.000000
# mean      22.042400      4.540900       75.086273      64.889480
# std        2.353074      2.301707       14.135381      14.838878
# min       18.000000      1.000000       23.679306      20.000000
# 25%       20.000000      3.000000       65.327423      54.802866
# 50%       22.000000      5.000000       75.259900      64.896744
# 75%       24.000000      7.000000       85.385109      75.061188
# max       26.000000      8.000000      100.000000     100.000000
#
#        Assignments_Avg   Quizzes_Avg  Participation_Score  Projects_Score  \
# count     10000.000000  10000.000000          9106.000000    10000.000000
# mean         70.021602     68.061132             5.976638       19.972879
# std          11.818102     13.889152             1.940925        4.939312
# min          30.000000     20.000000             1.000000        5.000000
# ...

# %%
df.to_csv('student_data.csv', index=False)

# %%
import pandas as pd
df = pd.read_csv("student_data1.csv")
bins = [0, 40, 50, 60, 70, 80, 90, 100]
labels = ["0-39", "40-49", "50-59", "60-69", "70-79", "80-89", "90-100"]

df["Score_Range"] = pd.cut(
    df["Final_Score"],
    bins=bins,
    labels=labels,
    right=True,          # include right side
    include_lowest=True
)

print(df["Score_Range"].value_counts().sort_index())
# Out:
# Score_Range
# 0-39      1914
# 40-49     1534
# 50-59     1988
# 60-69     2157
# 70-79     1593
# 80-89      641
# 90-100     173
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                 Age      Semester  Attendance (%)  Midterm_Score  \
# count  10000.000000  10000.000000     9397.000000   10000.000000
# mean      21.283700      4.155200       65.323773      50.999104
# std        2.478191      2.226254       11.410746      16.366411
# min       18.000000      1.000000       23.161495      20.000000
# 25%       19.000000      2.000000       57.753435      38.980000
# 50%       21.000000      4.000000       65.678707      52.135000
# 75%       23.000000      6.000000       73.319787      63.072500
# max       28.000000      8.000000      100.000000     100.000000
#
#        Assignments_Avg   Quizzes_Avg  Participation_Score  Projects_Score  \
# count     10000.000000  10000.000000          9131.000000    10000.000000
# mean         52.477626     42.422031             5.177750       43.786808
# std          16.131862     14.601556             1.896645       14.762405
# min           0.000000      0.000000             1.000000        0.000000
# ...

# %%
if (df['Final_Score']<90).any(): 
    df['Final_Score'] = df['Final_Score'] + 2

# %%
df["Score_Range"] = pd.cut(
    df["Final_Score"],
    bins=bins,
    labels=labels,
    right=True,          # include right side
    include_lowest=True
)

print(df["Score_Range"].value_counts().sort_index())
# Out:
# Score_Range
# 0-39      1667
# 40-49     1470
# 50-59     1870
# 60-69     2172
# 70-79     1781
# 80-89      800
# 90-100     212
# Name: count, dtype: int64

# %%
if (df['Final_Score']<90).any(): 
    df['Final_Score'] = df['Final_Score'] + 2

# %%
df["Score_Range"] = pd.cut(
    df["Final_Score"],
    bins=bins,
    labels=labels,
    right=True,          # include right side
    include_lowest=True
)

print(df["Score_Range"].value_counts().sort_index())
# Out:
# Score_Range
# 0-39      1445
# 40-49     1361
# 50-59     1781
# 60-69     2144
# 70-79     1933
# 80-89     1005
# 90-100     284
# Name: count, dtype: int64

# %%
if (df['Final_Score']<90).any(): 
    df['Final_Score'] = df['Final_Score'] + 2

# %%
df["Score_Range"] = pd.cut(
    df["Final_Score"],
    bins=bins,
    labels=labels,
    right=True,          # include right side
    include_lowest=True
)

print(df["Score_Range"].value_counts().sort_index())
# Out:
# Score_Range
# 0-39      1255
# 40-49     1231
# 50-59     1712
# 60-69     2111
# 70-79     2010
# 80-89     1229
# 90-100     373
# Name: count, dtype: int64

# %%
def calculate_grade(score):
    if pd.isna(score):
        return 'Unknown'
    if score >= 90:
        return 'O'
    elif score >= 80:
        return 'E'
    elif score >= 70:
        return 'A'
    elif score >= 60:
        return 'B'
    elif score >= 50:
        return 'C'
    elif score >= 40:
        return 'D'
    else:
        return 'F'


df['Grade'] = df['Final_Score'].apply(calculate_grade)

# %%
df["Grade"].value_counts()
# Out:
# Grade
# B    2109
# A    2014
# C    1712
# F    1253
# E    1230
# D    1230
# O     452
# Name: count, dtype: int64

# %%
df[df['Final_Score']>=90].value_counts().sum()
# Out:
# np.int64(193)

# %%
print(">= 90 :", (df["Final_Score"] >= 90).sum())
# Out:
# >= 90 : 452

# %%
print(">= 90 :", (df["Final_Score"] >= 90).sum())
print(">= 80 :", (df["Final_Score"] >= 80).sum())
print(">= 70 :", (df["Final_Score"] >= 70).sum())
print(">= 60 :", (df["Final_Score"] >= 60).sum())
print(">= 50 :", (df["Final_Score"] >= 50).sum())
print("< 50  :", (df["Final_Score"] < 50).sum())
# Out:
# >= 90 : 452
# >= 80 : 1682
# >= 70 : 3696
# >= 60 : 5805
# >= 50 : 7517
# < 50  : 2483

# %%
df = pd.read_csv('Student_data1.csv')

# %%
print("90-100 :", ((df["Final_Score"] >= 90) & (df["Final_Score"] <= 100)).sum())
print("80-89  :", ((df["Final_Score"] >= 80) & (df["Final_Score"] < 90)).sum())
print("70-79  :", ((df["Final_Score"] >= 70) & (df["Final_Score"] < 80)).sum())
print("60-69  :", ((df["Final_Score"] >= 60) & (df["Final_Score"] < 70)).sum())
print("50-59  :", ((df["Final_Score"] >= 50) & (df["Final_Score"] < 60)).sum())
print("40-49  :", ((df["Final_Score"] >= 40) & (df["Final_Score"] < 50)).sum())
print("< 40   :", (df["Final_Score"] < 40).sum())
# Out:
# 90-100 : 173
# 80-89  : 644
# 70-79  : 1594
# 60-69  : 2157
# 50-59  : 1984
# 40-49  : 1534
# < 40   : 1914

# %%
df.loc[df['Final_Score'] < 90, 'Final_Score'] += 2

# %%
print("90-100 :", ((df["Final_Score"] >= 90) & (df["Final_Score"] <= 100)).sum())
print("80-89  :", ((df["Final_Score"] >= 80) & (df["Final_Score"] < 90)).sum())
print("70-79  :", ((df["Final_Score"] >= 70) & (df["Final_Score"] < 80)).sum())
print("60-69  :", ((df["Final_Score"] >= 60) & (df["Final_Score"] < 70)).sum())
print("50-59  :", ((df["Final_Score"] >= 50) & (df["Final_Score"] < 60)).sum())
print("40-49  :", ((df["Final_Score"] >= 40) & (df["Final_Score"] < 50)).sum())
print("< 40   :", (df["Final_Score"] < 40).sum())
# Out:
# 90-100 : 241
# 80-89  : 799
# 70-79  : 1784
# 60-69  : 2172
# 50-59  : 1870
# 40-49  : 1467
# < 40   : 1667

# %%
df.loc[df['Final_Score'] < 90, 'Final_Score'] += 2

# %%
print("90-100 :", ((df["Final_Score"] >= 90) & (df["Final_Score"] <= 100)).sum())
print("80-89  :", ((df["Final_Score"] >= 80) & (df["Final_Score"] < 90)).sum())
print("70-79  :", ((df["Final_Score"] >= 70) & (df["Final_Score"] < 80)).sum())
print("60-69  :", ((df["Final_Score"] >= 60) & (df["Final_Score"] < 70)).sum())
print("50-59  :", ((df["Final_Score"] >= 50) & (df["Final_Score"] < 60)).sum())
print("40-49  :", ((df["Final_Score"] >= 40) & (df["Final_Score"] < 50)).sum())
print("< 40   :", (df["Final_Score"] < 40).sum())
# Out:
# 90-100 : 332
# 80-89  : 1006
# 70-79  : 1933
# 60-69  : 2144
# 50-59  : 1779
# 40-49  : 1362
# < 40   : 1444

# %%
import numpy as np

conditions = [
    df['Final_Score'] >= 90,
    df['Final_Score'] >= 80,
    df['Final_Score'] >= 70,
    df['Final_Score'] >= 60,
    df['Final_Score'] >= 50,
    df['Final_Score'] >= 40
]

grades = ['O', 'E', 'A', 'B', 'C', 'D']

df['Grade'] = np.select(conditions, grades, default='F')

print(df[['Final_Score','Grade']].head())
# Out:
#    Final_Score Grade
# 0        56.93     C
# 1        63.42     B
# 2        60.59     B
# 3        58.40     C
# 4        60.73     B

# %%
df['Grade'].value_counts()
# Out:
# Grade
# B    2144
# A    1933
# C    1779
# F    1444
# D    1362
# E    1006
# O     332
# Name: count, dtype: int64

# %%
df.to_csv('students_data.csv', index=False)

# %%
df1 = pd.read_csv("students_data.csv")

# %%
df['Grade'].value_counts()
# Out:
# Grade
# B    2144
# A    1933
# C    1779
# F    1444
# D    1362
# E    1006
# O     332
# Name: count, dtype: int64

# %%
df1[df1['Final_Score']==100]
# Out:
#       Gender  Age  Semester Branch Difficulty_Level  Attendance (%)  \
# 121     Male   18         2    ECE             Easy       83.099327
# 2457    Male   18         1    ECE             Easy       59.167144
# 2664    Male   18         2    ECE             Easy       82.729879
# 3080    Male   23         2    CSE             Easy      100.000000
# 3512    Male   19         1  Civil             Easy       81.165071
# 6604    Male   18         2    EEE             Easy       95.213828
# 6629    Male   21         2    CSE             Easy       92.319642
# 7522    Male   19         1     ME             Easy       88.504586
# 7576  Female   19         1     ME             Easy       93.504474
# 7662    Male   18         1    CSE             Easy       85.504458
# 7747    Male   23         4    ECE             Easy       82.387430
# 7937    Male   19         1    EEE             Hard       75.672854
# 8558    Male   21         6    EEE             Easy       96.972941
# ...

# %%
df1['Assignments_Avg'] = df1['Assignments_Avg'] / 10
df1['Quizzes_Avg'] = df1['Quizzes_Avg'] / 10

# %%
df1.describe()
# Out:
#                 Age      Semester  Attendance (%)  Midterm_Score  \
# count  10000.000000  10000.000000     9397.000000   10000.000000
# mean      21.283700      4.155200       65.323773      50.999104
# std        2.478191      2.226254       11.410746      16.366411
# min       18.000000      1.000000       23.161495      20.000000
# 25%       19.000000      2.000000       57.753435      38.980000
# 50%       21.000000      4.000000       65.678707      52.135000
# 75%       23.000000      6.000000       73.319787      63.072500
# max       28.000000      8.000000      100.000000     100.000000
#
#        Assignments_Avg   Quizzes_Avg  Participation_Score  Projects_Score  \
# count     10000.000000  10000.000000          9131.000000    10000.000000
# mean          5.247763      4.242203             5.177750       43.786808
# std           1.613186      1.460156             1.896645       14.762405
# min           0.000000      0.000000             1.000000        0.000000
# ...

# %%
df['Projects_Score'] = (df['Projects_Score'] / 100) * 20

# %%
df1.describe()
# Out:
#                 Age      Semester  Attendance (%)  Midterm_Score  \
# count  10000.000000  10000.000000     9397.000000   10000.000000
# mean      21.283700      4.155200       65.323773      50.999104
# std        2.478191      2.226254       11.410746      16.366411
# min       18.000000      1.000000       23.161495      20.000000
# 25%       19.000000      2.000000       57.753435      38.980000
# 50%       21.000000      4.000000       65.678707      52.135000
# 75%       23.000000      6.000000       73.319787      63.072500
# max       28.000000      8.000000      100.000000     100.000000
#
#        Assignments_Avg   Quizzes_Avg  Participation_Score  Projects_Score  \
# count     10000.000000  10000.000000          9131.000000    10000.000000
# mean          5.247763      4.242203             5.177750       43.786808
# std           1.613186      1.460156             1.896645       14.762405
# min           0.000000      0.000000             1.000000        0.000000
# ...

# %%
print(df1.columns)
# Out:
# Index(['Gender', 'Age', 'Semester', 'Branch', 'Difficulty_Level',
#        'Attendance (%)', 'Midterm_Score', 'Assignments_Avg', 'Quizzes_Avg',
#        'Participation_Score', 'Projects_Score', 'Study_Hours_per_Week',
#        'Internet_Access_at_Home', 'Parent_Education_Level',
#        'Family_Income_Level', 'Stress_Level', 'Sleep_Hours_per_Night',
#        'Final_Score', 'Grade', 'Pass/Fail'],
#       dtype='object')

# %%
print(df1['Projects_Score'].describe())
# Out:
# count    10000.000000
# mean        43.786808
# std         14.762405
# min          0.000000
# 25%         33.990000
# 50%         44.490000
# 75%         54.230000
# max         92.100000
# Name: Projects_Score, dtype: float64
